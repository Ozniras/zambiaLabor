# %%
import pandas as pd

# %%
lfs2012 = pd.read_stata('/home/ram22/dataDrive/dataProjects/povMap/zambiaLFSmapping/0_originalData/lfs/ZM_2012LFS_vFinal.dta')

# %%
lfs2012.describe()
# Out:
#             CLUSTER          WARD           CSA           SEA           SBN  \
# count  59247.000000  59247.000000  59247.000000  59247.000000  59247.000000
# mean    5318.196499     11.157730      5.724611      2.113862     62.258629
# std     2873.986833      6.871262      5.802559      1.059738     54.546738
# min     1001.000000      1.000000      1.000000      1.000000      1.000000
# 25%     3013.000000      6.000000      2.000000      1.000000     25.000000
# 50%     5048.000000     10.000000      4.000000      2.000000     50.000000
# 75%     8015.000000     16.000000      7.000000      3.000000     84.000000
# max    10050.000000     33.000000     51.000000      7.000000    999.000000
#
#                 HUN           HHN           BOB           PID      HH_count  \
# count  59247.000000  59247.000000  59247.000000  59247.000000  59247.000000
# mean       1.183368      1.013283      1.001435      3.708795      6.451078
# ...

# %%
pd.options.display.max_rows = 999
print(lfs2012.dtypes)
# Out:
# CLUSTER                    float64
# PROV                      category
# DIST                      category
# CONST                     category
# WARD                       float64
# REGION                    category
# CSA                        float64
# SEA                        float64
# SBN                        float64
# HUN                        float64
# HHN                        float64
# BOB                        float64
# PID                        float64
# HH_count                   float64
# A2                        category
# A4                        category
# nohead                     float64
# hasHead                    float64
# A3                         float64
# A5                        category
# SexOfHead                 category
# Age5Group                 category
# Age15Plus                 category
# Age5Grp65                 category
# A6                        category
# A7                        category
# A8                        category
# ...

# %%
print(len(lfs2012[lfs2012.A3 >= 5]))
print(lfs2012['C1'].describe())
lfs2012['C1'].value_counts()
lfs2012['labourforce'].value_counts()
# Out:
# 49263
# count                           49193
# unique                             11
# top       In paid employment/Business
# freq                            15291
# Name: C1, dtype: object
# 1.0    22382
# 2.0     2122
# Name: labourforce, dtype: int64

# %%
print(lfs2012.FA1.describe())
lfs2012.FA1.value_counts()
# Out:
# count        4765
# unique          5
# top       Monthly
# freq         4094
# Name: FA1, dtype: object
# Monthly               4094
# Daily                  278
# Other ...(Specify)     199
# Weekly                 122
# Every two weeks         72
# Name: FA1, dtype: int64

# %%
lfs2012.FA5B.describe()
# Out:
# count    4.348000e+03
# mean     1.709838e+06
# std      5.181202e+06
# min      7.680000e+02
# 25%      3.997500e+05
# 50%      8.000000e+05
# 75%      2.030000e+06
# max      2.400000e+08
# Name: FA5B, dtype: float64

# %%
print(lfs2012.FA6.describe())
lfs2012.FA6.value_counts()
# Out:
# count                               4073
# unique                                12
# top       K250,000 to less than K500,000
# freq                                 868
# Name: FA6, dtype: object
# K250,000 to less than K500,000      868
# K500,000 to less than K1 million    863
# K2m to less than K3 million         551
# Less than K250,000                  526
# K3m to less than K5 million         362
# K1m to less than K1.5 million       354
# K1.5m to less than K2 million       350
# K5m to less than K10 million        124
# K10m to less than K20 million        26
# Dont know                           22
# K20 million or more                  15
# Refused                              12
# Name: FA6, dtype: int64

# %%
lfs2012.FA8B.describe()
# Out:
# count    4.500000e+02
# mean     7.504204e+05
# std      5.683806e+06
# min      1.000000e+03
# 25%      8.000000e+04
# 50%      3.000000e+05
# 75%      5.700000e+05
# max      1.200000e+08
# Name: FA8B, dtype: float64

# %%
print(lfs2012.FA4B.describe())
# Out:
# count    6.020000e+02
# mean     4.129768e+05
# std      3.343586e+06
# min      2.410000e+02
# 25%      3.000000e+04
# 50%      1.000000e+05
# 75%      3.000000e+05
# max      8.115000e+07
# Name: FA4B, dtype: float64

# %%
lfs2012.FB1.value_counts()
# Out:
# Agriculture        6416
# Non-agriculture    4150
# Name: FB1, dtype: int64

# %%
lfs2012.FB6B.describe()
# Out:
# count    3.686000e+03
# mean     1.307193e+06
# std      9.895612e+06
# min     -1.355000e+07
# 25%      1.252500e+05
# 50%      3.200000e+05
# 75%      8.500000e+05
# max      5.000000e+08
# Name: FB6B, dtype: float64

# %%
print(lfs2012.FB7.describe())
lfs2012.FB7.value_counts()
# Out:
# count                   2960
# unique                    11
# top       Less than K250,000
# freq                    1187
# Name: FB7, dtype: object
# Less than K250,000                      1187
# K250,000 to less than K500,000           594
# K500,000 to less than K1,000,000         474
# K1,000,000 to less than K1,500,000       178
# K2,000,000 to less than K3,000,000       128
# K1,500,000 to less than K2,000,000       113
# K3,000,000 to less than K5,000,000       104
# Don't Know                                75
# K5,000,000 to less than K10,000,000       58
# K10,000,000 to less than K20,000,000      27
# K20,000,000 and above                     22
# Name: FB7, dtype: int64

# %%
lfs2012.FB13.describe()
# Out:
# count    4.188000e+03
# mean     1.874282e+06
# std      1.890731e+07
# min      0.000000e+00
# 25%      2.307500e+05
# 50%      5.750000e+05
# 75%      1.480000e+06
# max      1.199340e+09
# Name: FB13, dtype: float64

# %%
print(lfs2012.FB14.describe())
lfs2012.FB14.value_counts()
# Out:
# count                   3734
# unique                    11
# top       Less than K250,000
# freq                     972
# Name: FB14, dtype: object
# Less than K250,000                  972
# K250,000 to less than K500,000      730
# K500,000 to less than K1 million    717
# K1m to less than K1.5 million       372
# K2m to less than K3 million         279
# K1.5m to less than K2 million       234
# K3m to less than K5 million         183
# K5m to less than K10 million        162
# K10m to less than K20 million        42
# K20 million or more                  33
# Dont know                           10
# Name: FB14, dtype: int64

# %%
lfs2008Fin = pd.read_csv('~/dataDrive/dataProjects/povMap/zambiaLFSmapping/2_data/lfs2008csv/section5incomeEarnings.csv')

# %%
lfs2008Fin.describe()
# Out:
#                 DEO          PROV          DIST         CONST          WARD  \
# count  64618.000000  64618.000000  64618.000000  64618.000000  64618.000000
# mean      50.357501      4.883748    493.162942     74.188941     10.646631
# std       27.496071      2.574356    257.465262     42.584813      6.430074
# min        1.000000      1.000000    101.000000      1.000000      1.000000
# 25%       24.000000      3.000000    301.000000     38.000000      5.000000
# 50%       52.000000      5.000000    503.000000     74.000000     10.000000
# 75%       74.000000      7.000000    706.000000    110.000000     15.000000
# max       95.000000      9.000000    907.000000    150.000000     30.000000
#
#              REGION           CSA           SEA           SBN           HUN  \
# count  64618.000000  64618.000000  64618.000000  64618.000000  64618.000000
# mean       1.269337      3.505695      2.260933     68.075180      1.125940
# ...

# %%
print(lfs2008Fin.dtypes)
# Out:
# DEO           int64
# PROV          int64
# DIST          int64
# CONST         int64
# WARD          int64
# REGION        int64
# CSA           int64
# SEA           int64
# SBN           int64
# HUN           int64
# HHN           int64
# CATEGORY      int64
# PN            int64
# S5Q1         object
# S5Q2         object
# weight      float64
# dtype: object

# %%
print(lfs2008Fin.S5Q1.describe())
lfs2008Fin.S5Q1.value_counts()
# Out:
# count     64618
# unique       10
# top           7
# freq      23510
# Name: S5Q1, dtype: object
# 7    23510
# 1    16582
# 6    12048
# 4     4398
#       3842
# 3     2303
# 8     1039
# 2      792
# 5      100
# 9        4
# Name: S5Q1, dtype: int64

# %%
print(lfs2008Fin.S5Q2.describe())
lfs2008Fin.S5Q2.value_counts()
# Out:
# count     64618
# unique     1604
# top
# freq      27385
# Name: S5Q2, dtype: object
#              27385
# 200000        2267
# 300000        2002
# 100000        1974
# 150000        1567
# 50000         1373
# 500000        1329
# 400000        1145
# 600000        1030
# 250000        1002
# 1500000        786
# 20000          776
# 30000          702
# 40000          701
# 60000          695
# 800000         693
# 1000000        675
# 1200000        643
# 80000          630
# 120000         560
# 350000         546
# 700000         525
# 70000          454
# 450000         450
# 900000         441
# 25000          431
# 2000000        422
# 10000          372
# 3000000        360
# 180000         312
# 15000          286
# 90000          283
# 1800000        268
# 2500000        264
# 0              225
# 1300000        223
# 1400000        220
# 75000          209
# 750000         207
# 240000         195
# 1600000        179
# 160000         155
# 35000          148
# ...
